# %%
from hos import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
F(Kbar, Lbar)
# Out:
# 100.0

# %%
klplot(2)

# %%
SS(1)
# Out:
# 1.0

# %%
lerner(1)
# Out:
# w/r = 1.00, KLa = 3.00, KLm = 0.33

# %%
ssplot(1)
# Out:
# 1 1.0

# %%
edgeworth_plot(1)
# Out:
# w/r = 1.00, KLa = 3.00, KLm = 0.33

# %%
edgeworth(1)

# %%
interact(edgeworth,p=(0.5,2,0.1));
# Out:
# interactive(children=(FloatSlider(value=1.2000000000000002, description='p', max=2.0, min=0.5), IntSlider(valu…

# %%
PPF(30,alpha =0.8, beta=0.2)
# Out:
# (66.82503956964625, 45.709594400792724)

# %%
edgeworth(1)

# %%
interact(hos_eq, p=(0.1,2,0.1));
# Out:
# interactive(children=(FloatSlider(value=1.0, description='p', max=2.0, min=0.1), IntSlider(value=100, descript…
