# %% [markdown]
# # Example uses of `microeco` module
#
# This notebook demonstrates simple economic analysis and graphing functions for intermediate micro.
#
# At this point there's quite little in the cd library yet... mainly stuff for simple consumer plots.

# %% [markdown]
# Next cell useful while developing the module so changes are reflected immediately.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from cd import *
import numpy as np

# %% [markdown]
# ## Consumer Optimization plots

# %%
consume_plot(p=1, I=100)

# %% [markdown]
# Let's fix the limits of this plot so that we can then use `interact` from `ipywidgets` to see how plot reacts to parameter changes

# %%
def consume_plot2(p,I, a=ALPHA):
    consume_plot(p,I,a)
    plt.xlim(0,200)
    plt.ylim(0,200)

# %%
interact(consume_plot2,p=(0.2,5), I=(40,200),a=(0.2,0.8));
# Out:
# interactive(children=(FloatSlider(value=2.6, description='p', max=5.0, min=0.2), IntSlider(value=120, descript…
