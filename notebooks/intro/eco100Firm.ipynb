# %% [markdown]
# ## Competitive Firm Profits and supply

# %% [markdown]
# Run code in [Code Section](#Code-Section) first.

# %%
firm(10,100)
# Out:
# Qc = 50.00,    Profit  = 150.00

# %%
interact(firm,P=(2,20,1),F=(0,400,50));
# Out:
# interactive(children=(IntSlider(value=11, description='P', max=20, min=2), IntSlider(value=200, description='F…

# %% [markdown]
# ## Monopoly

# %% [markdown]
# We specify the inverse demand curve.

# %% [markdown]
# ## Code Section

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
from ipywidgets import interact, interact_manual, fixed
import numpy as np


plt.style.use('bmh')
plt.rcParams["figure.figsize"] = [7,7]
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False
plt.rcParams["font.size"] = 18

# %%
Q = np.linspace(0.1,100,num=100)
F=10
P = 10
c = 0.1
b = 2

# %%
def TC(Q,F=F,c=c):
    return F + c*Q**b

def MC(Q,F=F,c=c):
    return b*c*Q**(b-1)

def profit(P,Q,F=F,c=c):
    return P*Q - TC(Q,F,c)

def isoprofplot(Q,profit=0, F=F, c=c):
    return (profit + TC(Q,F,c))/Q

def zeroprofitprice(F,c):
    Qmin = (F/c*(b-1))**(1/b)
    return MC(Qmin, F, c)

# %%
zeroprofitprice(100,c)
# Out:
# 6.324555320336759

# %%
def firm(P,F):
    qc = (P/(b*c))**(1/(b-1))
    print(r'Qc = {:.2f},    Profit  = {:.2f}'.format(qc,profit(P,qc,F,c)))
    fig, ax = plt.subplots(3,1,figsize=(8,12))
    ax[0].plot(Q,P*Q)
    ax[0].plot(Q, TC(Q,F), lw=2.5)
    ax[0].text(90, TC(100), r'$TC(Q)$', fontsize=15)
    ax[0].text(15, P*30, r'$TR=P\cdot Q$', fontsize=15)
    ax[0].axvline(qc,linestyle='dashed')

    ax[1].plot(Q, P*Q - TC(Q,F,c))
    ax[1].axhline(0,linestyle='dashed')
    ax[1].axvline(qc,linestyle='dashed')
    ax[2].axvline(qc,linestyle='dashed')
    ax[1].set_ylim(-100,300)
  
    ax[2].axhline(P)
    ax[2].set_ylim(0,25)
    ax[2].plot(Q,MC(Q),'red')
    ax[2].set_xlabel('Q -- quantity')
    ax[2].set_ylabel('Price')
    ax[2].text(90, MC(80), r'MC', fontsize=15)
    ax[2].text(102, P, r'P', fontsize=15)
    # ax[2].plot(Q, isoprofplot(Q, profit=0, F=F,c=c))
    ax[2].axhline(zeroprofitprice(F,c), linestyle = ':')
    ax[2].text(70, zeroprofitprice(F,c)-1,'zero profit price')

# %%
A = 15
b = 0.20


def P(Q, A=A, b=b):
    return A - b*Q

def TR(Q):
    return P(Q)*Q

def Profits(Q):
    return TR(Q) - TC(Q,F,c)

# %%
#plt.plot(Q,Profits(Q))
#plt.plot(Q,TR(Q))
plt.plot(Q,TC(Q,F=100))
